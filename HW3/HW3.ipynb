# %%
import numpy as np
import pandas as pd
from scipy.io import arff
from sklearn.model_selection import LeaveOneOut
from sklearn.metrics import accuracy_score

# %%
def splitdf(df):
    y = df[df.columns[-1]].to_numpy()
    x = df[df.columns[:-1]].to_numpy()
    return x,y

# %%
def euclid_dist(x,y):
    return np.sqrt(np.sum((np.array(x)-np.array(y))**2))

# %%
def KNN(k,x,y,xnew):
    dists = []
    for i in range(len(x)):
        dists.append((y[i],euclid_dist(x[i],xnew)))
    dists.sort(key=lambda x:x[1])
    neighbors=[]
    for i in range(k):
        neighbors.append(dists[i][0])
    return neighbors

# %%
def KNN_predict(k,X_train,y_train,xtest):
    preds = []
    for xnew in xtest:
        neighbors = KNN(k,X_train,y_train,xnew)
        pred = max(neighbors,key=neighbors.count)
        preds.append(pred)
    return preds

# %%
data = arff.loadarff('veh-prime.arff')
df = pd.DataFrame(data[0])

# %%
def pearson(x,y):
    sum_sq_x = 0
    sum_sq_y = 0
    sum_coproduct = 0
    mean_x = 0
    mean_y = 0
    N = len(x)
    for i in range(N):
        sum_sq_x += x[i] * x[i]
        sum_sq_y += y[i] * y[i]
        sum_coproduct += x[i] * y[i]
        mean_x += x[i]
        mean_y += y[i]
    mean_x = mean_x / N
    mean_y = mean_y / N
    pop_sd_x = np.sqrt((sum_sq_x/N) - (mean_x * mean_x))
    pop_sd_y = np.sqrt((sum_sq_y / N) - (mean_y * mean_y))
    cov_x_y = (sum_coproduct / N) - (mean_x * mean_y)
    correlation = cov_x_y / (pop_sd_x * pop_sd_y)
    return correlation

# %%
df['CLASS']=df['CLASS'].str.decode('ascii').map({"car": 1, "noncar": 0})

# %%
df
# Out:
#         f0     f1     f2     f3     f4     f5     f6     f7     f8     f9  \
# 0    0.063  0.160  0.509 -0.967  0.058  0.000  0.874  0.271  1.307 -0.011
# 1   -0.037 -0.325 -0.626 -0.029  0.121 -0.409 -0.002 -0.835 -0.595 -0.253
# 2   -0.000  1.253  0.833 -0.970  1.516  0.014 -0.378  1.197  0.546 -0.402
# 3   -0.743 -0.082 -0.626  0.723 -0.006 -0.000 -0.080 -0.297  0.166  0.311
# 4   -0.939 -1.054 -0.140  0.036 -0.766  0.000 -0.272  1.077  5.236 -0.366
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 841  0.072 -0.082 -0.950  0.359  0.311  0.368 -0.259  0.420  0.292 -0.070
# 842 -0.555 -0.568  0.184 -0.920  0.121  0.883 -0.006 -0.177  0.546  0.282
# 843 -0.703  1.496  1.481 -0.529  1.199 -0.085 -0.980  1.585  0.673 -0.553
# 844  0.296 -0.932 -1.436  0.113 -0.259  0.905  0.409 -0.685 -0.468 -0.053
# 845  0.410 -1.054 -1.436 -0.252 -1.020  0.302  0.772 -1.373 -0.849  0.014
#
#      ...    f27    f28    f29    f30    f31    f32    f33    f34    f35  CLASS
# 0    ... -0.924 -0.077  0.108 -0.003  0.381 -0.314  0.929  0.184 -0.001      0
# 1    ...  0.270  0.533  0.152 -0.978  0.157  0.011 -0.254  0.453 -0.621      0
# 2    ... -0.408  1.550  0.010 -0.652 -0.403 -0.151  0.000  0.049 -0.113      1
# 3    ...  0.819 -0.077 -0.099 -0.001 -0.291  1.633  0.686  1.528 -0.000      0
# 4    ...  0.676  0.533 -0.003  0.122 -0.179 -1.449  0.024 -1.698  0.083      0
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 841  ...  0.005  0.127  0.380 -0.001  1.388 -0.151  0.291 -0.085  0.000      1
# 842  ...  0.039 -1.093  0.066  0.002  0.829 -0.476  0.924  0.184  0.170      0
# 843  ... -0.704 -0.687  0.059 -0.294 -0.963 -0.314 -0.204  0.722 -0.386      1
# 844  ... -0.156 -1.297 -0.238 -0.000  1.388  0.173  0.016 -0.085  0.873      1
# 845  ...  0.000 -1.093 -0.934  0.457  0.605 -0.476 -0.122 -0.757 -0.355      0
#
# [846 rows x 37 columns]

# %%
features = ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10',
       'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20',
       'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29', 'f30',
       'f31', 'f32', 'f33', 'f34', 'f35']

# %%
featdict = {}
for feat in features:
  featdict[feat] = np.abs(pearson(df[feat],df['CLASS']))

# %%
featdf = pd.DataFrame(featdict,index=['R'])
featdf = featdf.T

# %%
featdf.sort_values(by='R',ascending = False)
# Out:
#             R
# f4   0.436922
# f13  0.368269
# f14  0.368224
# f16  0.366025
# f7   0.352141
# f22  0.351350
# f26  0.341043
# f1   0.308811
# f20  0.299049
# f31  0.290783
# f34  0.266093
# f2   0.195732
# f28  0.156904
# f25  0.153096
# f19  0.137636
# f17  0.113945
# f32  0.093174
# f8   0.087773
# f0   0.069795
# f10  0.056876
# f21  0.056605
# f11  0.042117
# f33  0.038810
# f6   0.035295
# f15  0.031478
# f35  0.030855
# f29  0.020829
# f18  0.017931
# f27  0.015606
# f9   0.013005
# f3   0.009214
# f30  0.008955
# f24  0.007780
# f23  0.005508
# f12  0.002179
# f5   0.000098

# %%
feats = ['f4', 'f13', 'f14', 'f16', 'f7', 'f22', 'f26', 'f1', 'f20', 'f31',
       'f34', 'f2', 'f28', 'f25', 'f19', 'f17', 'f32', 'f8', 'f0', 'f10',
       'f21', 'f11', 'f33', 'f6', 'f15', 'f35', 'f29', 'f18', 'f27', 'f9',
       'f3', 'f30', 'f24', 'f23', 'f12', 'f5']

# %%
results = {}
for m in range(1,len(feats)):
  tempdf  = df[feats[:m]+['CLASS']]
  loo = LeaveOneOut()
  X,y = splitdf(tempdf)
  ytrue = []
  ypred = []
  for train_index, test_index in loo.split(tempdf):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    ytrue.append(y_test)
    ypred.append(KNN_predict(7,X_train,y_train,X_test))
  results[m] = accuracy_score(ytrue,ypred)
resultdf = pd.DataFrame(results,index=['accuracy'])

# %%
resultdf.T.sort_values(by='accuracy',ascending = False)
# Out:
#     accuracy
# 20  0.950355
# 18  0.946809
# 31  0.945626
# 29  0.945626
# 23  0.945626
# 24  0.944444
# 34  0.943262
# 30  0.943262
# 22  0.943262
# 33  0.942080
# 28  0.942080
# 19  0.942080
# 26  0.940898
# 21  0.940898
# 32  0.938534
# 27  0.937352
# 25  0.936170
# 17  0.933806
# 35  0.931442
# 16  0.916076
# 15  0.908983
# 12  0.904255
# 11  0.901891
# 9   0.894799
# 14  0.891253
# 13  0.888889
# 10  0.885343
# 8   0.874704
# 7   0.861702
# 6   0.836879
# 5   0.834515
# 4   0.833333
# 3   0.822695
# 2   0.795508
# 1   0.722222

# %%
def SFS(df,features,selection,accuracy=0):

# %%
features = ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10',
       'f11', 'f12', 'f13','f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20',
       'f21', 'f22', 'f23', 'f24', 'f25', 'f26', 'f27', 'f28', 'f29', 'f30',
       'f31', 'f32', 'f33', 'f34', 'f35']
selection = []
accuracy = 0
results = {}
while True:
  for feat in features:
    print(feat,selection)
    tempselect = []
    tempselect.extend(selection)
    tempselect.append(feat)
    tempdf  = df[tempselect+['CLASS']]
    loo = LeaveOneOut()
    X,y = splitdf(tempdf)
    ytrue = []
    ypred = []
    for train_index, test_index in loo.split(tempdf):
      X_train, X_test = X[train_index], X[test_index]
      y_train, y_test = y[train_index], y[test_index]
      ytrue.append(y_test)
      ypred.append(KNN_predict(7,X_train,y_train,X_test))
    results[feat] = accuracy_score(ytrue,ypred)
    print(results[feat])
  bestfeat = max(results, key=results.get)
  if results[max(results, key=results.get)] > accuracy:
    features.remove(bestfeat)
    selection.append(bestfeat)
    print(selection, results[max(results, key=results.get)])
    accuracy = results[max(results, key=results.get)]
  else:
    break
# Out:
# f0 []
# 0.508274231678487
# f1 []
# 0.6335697399527187
# f2 []
# 0.6749408983451537
# f3 []
# 0.48817966903073284
# f4 []
# 0.7222222222222222
# f5 []
# 0.5130023640661938
# f6 []
# 0.46099290780141844
# f7 []
# 0.66548463356974
# f8 []
# 0.5721040189125296
# f9 []
# 0.5070921985815603
# f10 []
# 0.5697399527186762
# f11 []
# 0.46335697399527187
# f12 []
# 0.5153664302600472
# f13 []
# 0.7387706855791962
# f14 []
# 0.7635933806146572
# f15 []
# 0.5236406619385343
# f16 []
# 0.710401891252955
# f17 []
# 0.5094562647754137
# f18 []
# 0.5047281323877069
# f19 []
# 0.6442080378250591
# f20 []
# 0.7434988179669031
# f21 []
# 0.5023640661938534
# f22 []
# 0.7411347517730497
# f23 []
# 0.5106382978723404
# f24 []
# 0.5118203309692672
# f25 []
# 0.6382978723404256
# f26 []
# 0.599290780141844
# f27 []
# 0.5130023640661938
# f28 []
# 0.5319148936170213
# f29 []
# 0.5307328605200946
# f30 []
# 0.5295508274231678
# f31 []
# 0.6134751773049646
# f32 []
# 0.5543735224586288
# f33 []
# 0.5070921985815603
# f34 []
# 0.5295508274231678
# f35 []
# 0.5023640661938534
# ['f14'] 0.7635933806146572
# f0 ['f14']
# 0.7411347517730497
# f1 ['f14']
# 0.7706855791962175
# f2 ['f14']
# 0.8096926713947991
# f3 ['f14']
# 0.7446808510638298
# f4 ['f14']
# 0.8120567375886525
# f5 ['f14']
# 0.7399527186761229
# f6 ['f14']
# 0.710401891252955
# f7 ['f14']
# 0.7600472813238771
# f8 ['f14']
# 0.8156028368794326
# f9 ['f14']
# 0.7600472813238771
# f10 ['f14']
# 0.8711583924349882
# f11 ['f14']
# 0.735224586288416
# f12 ['f14']
# 0.7505910165484634
# f13 ['f14']
# 0.8215130023640662
# f15 ['f14']
# 0.7434988179669031
# f16 ['f14']
# 0.8014184397163121
# f17 ['f14']
# 0.7387706855791962
# f18 ['f14']
# 0.735224586288416
# f19 ['f14']
# 0.8238770685579196
# f20 ['f14']
# 0.7730496453900709
# f21 ['f14']
# 0.7304964539007093
# f22 ['f14']
# 0.7683215130023641
# f23 ['f14']
# 0.7364066193853428
# f24 ['f14']
# 0.7494089834515366
# f25 ['f14']
# 0.7777777777777778
# f26 ['f14']
# 0.789598108747045
# f27 ['f14']
# 0.7458628841607565
# f28 ['f14']
# 0.7399527186761229
# f29 ['f14']
# 0.7304964539007093
# f30 ['f14']
# 0.7375886524822695
# f31 ['f14']
# 0.7612293144208038
# f32 ['f14']
# 0.7695035460992907
# f33 ['f14']
# 0.7328605200945626
# f34 ['f14']
# 0.7706855791962175
# f35 ['f14']
# 0.75177304964539
# ['f14', 'f10'] 0.8711583924349882
# f0 ['f14', 'f10']
# 0.8475177304964538
# f1 ['f14', 'f10']
# 0.8699763593380615
# f2 ['f14', 'f10']
# 0.892434988179669
# f3 ['f14', 'f10']
# 0.8439716312056738
# f4 ['f14', 'f10']
# 0.875886524822695
# f5 ['f14', 'f10']
# 0.8522458628841607
# f6 ['f14', 'f10']
# 0.8215130023640662
# f7 ['f14', 'f10']
# 0.8652482269503546
# f8 ['f14', 'f10']
# 0.8794326241134752
# f9 ['f14', 'f10']
# 0.8416075650118203
# f11 ['f14', 'f10']
# 0.8416075650118203
# f12 ['f14', 'f10']
# 0.8297872340425532
# f13 ['f14', 'f10']
# 0.8664302600472813
# f15 ['f14', 'f10']
# 0.8451536643026005
# f16 ['f14', 'f10']
# 0.8723404255319149
# f17 ['f14', 'f10']
# 0.8439716312056738
# f18 ['f14', 'f10']
# 0.8498817966903073
# f19 ['f14', 'f10']
# 0.9030732860520094
# f20 ['f14', 'f10']
# 0.8569739952718676
# f21 ['f14', 'f10']
# 0.8356973995271868
# f22 ['f14', 'f10']
# 0.8664302600472813
# f23 ['f14', 'f10']
# 0.8451536643026005
# f24 ['f14', 'f10']
# 0.8427895981087471
# f25 ['f14', 'f10']
# 0.8817966903073287
# f26 ['f14', 'f10']
# 0.8416075650118203
# f27 ['f14', 'f10']
# 0.8557919621749409
# f28 ['f14', 'f10']
# 0.8546099290780141
# f29 ['f14', 'f10']
# 0.8392434988179669
# f30 ['f14', 'f10']
# 0.8215130023640662
# f31 ['f14', 'f10']
# 0.8806146572104019
# f32 ['f14', 'f10']
# 0.8498817966903073
# f33 ['f14', 'f10']
# 0.8368794326241135
# f34 ['f14', 'f10']
# 0.8546099290780141
# f35 ['f14', 'f10']
# 0.8416075650118203
# ['f14', 'f10', 'f19'] 0.9030732860520094
# f0 ['f14', 'f10', 'f19']
# 0.892434988179669
# f1 ['f14', 'f10', 'f19']
# 0.9160756501182034
# f2 ['f14', 'f10', 'f19']
# 0.9137115839243499
# f3 ['f14', 'f10', 'f19']
# 0.8817966903073287
# f4 ['f14', 'f10', 'f19']
# 0.9196217494089834
# f5 ['f14', 'f10', 'f19']
# 0.8853427895981087
# f6 ['f14', 'f10', 'f19']
# 0.8936170212765957
# f7 ['f14', 'f10', 'f19']
# 0.91725768321513
# f8 ['f14', 'f10', 'f19']
# 0.9361702127659575
# f9 ['f14', 'f10', 'f19']
# 0.8912529550827423
# f11 ['f14', 'f10', 'f19']
# 0.9030732860520094
# f12 ['f14', 'f10', 'f19']
# 0.8947990543735225
# f13 ['f14', 'f10', 'f19']
# 0.9054373522458629
# f15 ['f14', 'f10', 'f19']
# 0.8900709219858156
# f16 ['f14', 'f10', 'f19']
# 0.9137115839243499
# f17 ['f14', 'f10', 'f19']
# 0.8936170212765957
# f18 ['f14', 'f10', 'f19']
# 0.8971631205673759
# f20 ['f14', 'f10', 'f19']
# 0.9101654846335697
# f21 ['f14', 'f10', 'f19']
# 0.8877068557919622
# f22 ['f14', 'f10', 'f19']
# 0.9054373522458629
# f23 ['f14', 'f10', 'f19']
# 0.8747044917257684
# f24 ['f14', 'f10', 'f19']
# 0.892434988179669
# f25 ['f14', 'f10', 'f19']
# 0.9231678486997635
# f26 ['f14', 'f10', 'f19']
# 0.9078014184397163
# f27 ['f14', 'f10', 'f19']
# 0.8936170212765957
# f28 ['f14', 'f10', 'f19']
# 0.9054373522458629
# f29 ['f14', 'f10', 'f19']
# 0.8971631205673759
# f30 ['f14', 'f10', 'f19']
# 0.8900709219858156
# f31 ['f14', 'f10', 'f19']
# 0.875886524822695
# f32 ['f14', 'f10', 'f19']
# 0.9148936170212766
# f33 ['f14', 'f10', 'f19']
# 0.8912529550827423
# f34 ['f14', 'f10', 'f19']
# 0.8983451536643026
# f35 ['f14', 'f10', 'f19']
# 0.8829787234042553
# ['f14', 'f10', 'f19', 'f8'] 0.9361702127659575
# f0 ['f14', 'f10', 'f19', 'f8']
# 0.9219858156028369
# f1 ['f14', 'f10', 'f19', 'f8']
# 0.9432624113475178
# f2 ['f14', 'f10', 'f19', 'f8']
# 0.9302600472813238
# f3 ['f14', 'f10', 'f19', 'f8']
# 0.9219858156028369
# f4 ['f14', 'f10', 'f19', 'f8']
# 0.933806146572104
# f5 ['f14', 'f10', 'f19', 'f8']
# 0.9243498817966903
# f6 ['f14', 'f10', 'f19', 'f8']
# 0.9243498817966903
# f7 ['f14', 'f10', 'f19', 'f8']
# 0.9562647754137116
# f9 ['f14', 'f10', 'f19', 'f8']
# 0.9290780141843972
# f11 ['f14', 'f10', 'f19', 'f8']
# 0.9267139479905437
# f12 ['f14', 'f10', 'f19', 'f8']
# 0.9196217494089834
# f13 ['f14', 'f10', 'f19', 'f8']
# 0.9326241134751773
# f15 ['f14', 'f10', 'f19', 'f8']
# 0.9208037825059102
# f16 ['f14', 'f10', 'f19', 'f8']
# 0.9349881796690307
# f17 ['f14', 'f10', 'f19', 'f8']
# 0.9267139479905437
# f18 ['f14', 'f10', 'f19', 'f8']
# 0.9290780141843972
# f20 ['f14', 'f10', 'f19', 'f8']
# 0.9349881796690307
# f21 ['f14', 'f10', 'f19', 'f8']
# 0.9267139479905437
# f22 ['f14', 'f10', 'f19', 'f8']
# 0.9302600472813238
# f23 ['f14', 'f10', 'f19', 'f8']
# 0.9113475177304965
# f24 ['f14', 'f10', 'f19', 'f8']
# 0.9160756501182034
# f25 ['f14', 'f10', 'f19', 'f8']
# 0.9373522458628841
# f26 ['f14', 'f10', 'f19', 'f8']
# 0.9456264775413712
# f27 ['f14', 'f10', 'f19', 'f8']
# 0.9125295508274232
# f28 ['f14', 'f10', 'f19', 'f8']
# 0.925531914893617
# f29 ['f14', 'f10', 'f19', 'f8']
# 0.9208037825059102
# f30 ['f14', 'f10', 'f19', 'f8']
# 0.925531914893617
# f31 ['f14', 'f10', 'f19', 'f8']
# 0.9160756501182034
# f32 ['f14', 'f10', 'f19', 'f8']
# 0.9408983451536643
# f33 ['f14', 'f10', 'f19', 'f8']
# 0.9219858156028369
# f34 ['f14', 'f10', 'f19', 'f8']
# 0.9444444444444444
# f35 ['f14', 'f10', 'f19', 'f8']
# 0.9219858156028369
# ['f14', 'f10', 'f19', 'f8', 'f7'] 0.9562647754137116
# f0 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9515366430260047
# f1 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9539007092198581
# f2 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9515366430260047
# f3 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9479905437352246
# f4 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9479905437352246
# f5 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9408983451536643
# f6 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9408983451536643
# f9 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9432624113475178
# f11 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9432624113475178
# f12 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9408983451536643
# f13 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9515366430260047
# f15 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9397163120567376
# f16 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.950354609929078
# f17 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9456264775413712
# f18 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9432624113475178
# f20 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9515366430260047
# f21 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9527186761229315
# f22 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.950354609929078
# f23 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9397163120567376
# f24 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.933806146572104
# f25 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.958628841607565
# f26 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9432624113475178
# f27 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9491725768321513
# f28 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9314420803782506
# f29 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9408983451536643
# f30 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9432624113475178
# f31 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9314420803782506
# f32 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9491725768321513
# f33 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9397163120567376
# f34 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9491725768321513
# f35 ['f14', 'f10', 'f19', 'f8', 'f7']
# 0.9326241134751773
# ['f14', 'f10', 'f19', 'f8', 'f7', 'f25'] 0.958628841607565
# f0 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.950354609929078
# f1 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9621749408983451
# f2 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9539007092198581
# f3 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9515366430260047
# f4 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.958628841607565
# f5 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9491725768321513
# f6 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9468085106382979
# f9 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.950354609929078
# f11 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9479905437352246
# f12 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9550827423167849
# f13 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9539007092198581
# f15 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.958628841607565
# f16 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9609929078014184
# f17 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9385342789598109
# f18 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9527186761229315
# f20 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9515366430260047
# f21 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9515366430260047
# f22 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.950354609929078
# f23 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9432624113475178
# f24 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9515366430260047
# f26 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9456264775413712
# f27 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9574468085106383
# f28 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9349881796690307
# f29 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9468085106382979
# f30 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9550827423167849
# f31 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9278959810874704
# f32 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9491725768321513
# f33 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9562647754137116
# f34 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9444444444444444
# f35 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25']
# 0.9468085106382979
# ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1'] 0.9621749408983451
# f0 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9562647754137116
# f2 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.958628841607565
# f3 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9550827423167849
# f4 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9562647754137116
# f5 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9444444444444444
# f6 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9456264775413712
# f9 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9621749408983451
# f11 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9515366430260047
# f12 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9562647754137116
# f13 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9574468085106383
# f15 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9515366430260047
# f16 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.958628841607565
# f17 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9527186761229315
# f18 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9539007092198581
# f20 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9598108747044918
# f21 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9539007092198581
# f22 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9598108747044918
# f23 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9456264775413712
# f24 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9550827423167849
# f26 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9456264775413712
# f27 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9562647754137116
# f28 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9432624113475178
# f29 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9515366430260047
# f30 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.958628841607565
# f31 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9326241134751773
# f32 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.950354609929078
# f33 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.950354609929078
# f34 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9527186761229315
# f35 ['f14', 'f10', 'f19', 'f8', 'f7', 'f25', 'f1']
# 0.9491725768321513
